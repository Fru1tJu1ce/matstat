# %%
import pandas as pd
import statsmodels.formula.api as smf


link = r'http://d396qusza40orc.cloudfront.net/statistics/lec_resources/states.csv'
df = pd.read_csv(link)
model = smf.ols(formula='poverty ~ metro_res + white + hs_grad + female_house', data=df)
result = model.fit()
new_frame = df[['metro_res', 'white', 'hs_grad', 'poverty', 'female_house']].copy()

# %%
import pandas as pd
import numpy as np

corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_91d34_row0_col0, #T_91d34_row1_col1, #T_91d34_row2_col2, #T_91d34_row3_col3, #T_91d34_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_91d34_row0_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_91d34_row0_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_91d34_row0_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_91d34_row0_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_91d34_row1_col0, #T_91d34_row1_col4, #T_91d34_row2_col3, #T_91d34_row3_col2, #T_91d34_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_91d34_row1_col2, #T_91d34_row2_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_91d34_row1_col3, #T_91d34_row3_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_91d34_row2_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_91d34_row2_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_91d34_row3_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_91d34_row3_col4, #T_91d34_row4_col3 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_91d34_row4_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_91d34_row4_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_91d34_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >metro_res</th>
#       <th class="col_heading level0 col1" >white</th>
#       <th class="col_heading level0 col2" >hs_grad</th>
#       <th class="col_heading level0 col3" >poverty</th>
#       <th class="col_heading level0 col4" >female_house</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91d34_level0_row0" class="row_heading level0 row0" >metro_res</th>
#       <td id="T_91d34_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_91d34_row0_col1" class="data row0 col1" >-0.342442</td>
#       <td id="T_91d34_row0_col2" class="data row0 col2" >0.018110</td>
#       <td id="T_91d34_row0_col3" class="data row0 col3" >-0.204235</td>
#       <td id="T_91d34_row0_col4" class="data row0 col4" >0.300062</td>
#     </tr>
#     <tr>
#       <th id="T_91d34_level0_row1" class="row_heading level0 row1" >white</th>
#       <td id="T_91d34_row1_col0" class="data row1 col0" >-0.342442</td>
#       <td id="T_91d34_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_91d34_row1_col2" class="data row1 col2" >0.238156</td>
#       <td id="T_91d34_row1_col3" class="data row1 col3" >-0.308520</td>
#       <td id="T_91d34_row1_col4" class="data row1 col4" >-0.751394</td>
#     </tr>
#     <tr>
#       <th id="T_91d34_level0_row2" class="row_heading level0 row2" >hs_grad</th>
#       <td id="T_91d34_row2_col0" class="data row2 col0" >0.018110</td>
#       <td id="T_91d34_row2_col1" class="data row2 col1" >0.238156</td>
#       <td id="T_91d34_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_91d34_row2_col3" class="data row2 col3" >-0.746858</td>
#       <td id="T_91d34_row2_col4" class="data row2 col4" >-0.611867</td>
#     </tr>
#     <tr>
#       <th id="T_91d34_level0_row3" class="row_heading level0 row3" >poverty</th>
#       <td id="T_91d34_row3_col0" class="data row3 col0" >-0.204235</td>
#       <td id="T_91d34_row3_col1" class="data row3 col1" >-0.308520</td>
#       <td id="T_91d34_row3_col2" class="data row3 col2" >-0.746858</td>
#       <td id="T_91d34_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_91d34_row3_col4" class="data row3 col4" >0.525397</td>
#     </tr>
#     <tr>
#       <th id="T_91d34_level0_row4" class="row_heading level0 row4" >female_house</th>
#       <td id="T_91d34_row4_col0" class="data row4 col0" >0.300062</td>
#       <td id="T_91d34_row4_col1" class="data row4 col1" >-0.751394</td>
#       <td id="T_91d34_row4_col2" class="data row4 col2" >-0.611867</td>
#       <td id="T_91d34_row4_col3" class="data row4 col3" >0.525397</td>
#       <td id="T_91d34_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt


fig, axes = plt.subplots(5,5)
fig.suptitle("Scatter plots", fontsize=30)
plt.rcParams['figure.figsize'] = [30, 30]


for frame_1 in enumerate(new_frame):
    for frame_2 in enumerate(new_frame):
        if frame_2[0] <= frame_1[0]:
            axes[frame_1[0], frame_2[0]].scatter(df[frame_2[1]], df[frame_1[1]])
            axes[frame_1[0], frame_2[0]].tick_params(labelsize=20)
        else:
            axes[frame_1[0], frame_2[0]].axis('off')

        if frame_2[0] == 0:
            axes[frame_1[0], frame_2[0]].set_ylabel(frame_1[1], fontsize=25)
        if frame_1[0] == 4:
            axes[frame_1[0], frame_2[0]].set_xlabel(frame_2[1], fontsize=25)
